# %% [markdown]
# # Benchmark Summary
#
# ## Construction
#
# > **Note**
# > Currently, GPU construction is not optimized. Matrices are initially constructed on the CPU and then copied into the GPU.
# > GPU kernels will be implemented in future versions.
#
# ![image.png](attachment:image.png)
#
# ## Memory
#
# > **Note**
# > For sparse matrices, the memory size may vary based on the number of elements included in the Hamiltonian.
#
# ![image-2.png](attachment:image-2.png)
#
# ## Spectrum
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# ## Dynamics (RK4)
#
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# ## Dynamics (Cheb)
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
#
# ## Dynamics (RK4 vs Cheb)
#
# ![image-9.png](attachment:image-9.png)
